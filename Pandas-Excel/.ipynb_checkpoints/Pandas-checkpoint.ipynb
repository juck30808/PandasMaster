# %% [markdown]
# ### Pandas
#
# - https://pbpython.com/pandas-release-17.html

# %%
from __future__ import print_function
import pandas as pd

sales_df = pd.read_excel('data/df-sample-sales3.xlsx')
sales_df.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                 date
# 0       86.69    3380.91  2014-01-01 07:21:51
# 1       63.16     -63.16  2014-01-01 10:00:47
# 2       90.70    2086.10  2014-01-01 13:24:58
# 3       21.05     863.05  2014-01-01 15:05:22
# 4       83.21     499.26  2014-01-01 23:26:55

# %% [markdown]
# 我們再次使用我們的簡單銷售數據來顯示幾個月的購買歷史。 prod_group列只是一種根據SKU將產品分成不同類別的方法。
#
# 現在，讓我們創建一個數據透視表。這裡的關鍵是，數據透視表創建了一個MultiIndex，當我們試圖保存到Excel時，這將導致問題。

# %%
sales_df["prod_group"] = sales_df["sku"].str[0:2]
sales_df.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                 date prod_group
# 0       86.69    3380.91  2014-01-01 07:21:51         B1
# 1       63.16     -63.16  2014-01-01 10:00:47         S2
# 2       90.70    2086.10  2014-01-01 13:24:58         B1
# 3       21.05     863.05  2014-01-01 15:05:22         S1
# 4       83.21     499.26  2014-01-01 23:26:55         S2

# %%
sales_summary = pd.pivot_table(sales_df, index=["name"],
                               columns=["prod_group"],
                               values=["ext price", "quantity"])
sales_summary
# Out:
#                                    ext price                            \
# prod_group                                B1           S1           S2
# name
# Barton LLC                       1171.640278  1306.237600  1647.786190
# Cronin, Oberbrunner and Spencer  1387.616842  1342.598571  1302.787407
# Frami, Hills and Schmidt         1475.132143  1439.311875  1401.317857
# Fritsch, Russel and Anderson     1372.360286  1188.012857  1569.353200
# Halvorson, Crona and Champlin    1356.640000  1267.756667   983.963158
# Herman LLC                       1363.706923   980.005000  1586.427000
# Jerde-Hilpert                    1361.323333  1384.032174  1085.909697
# Kassulke, Ondricka and Metz      1092.958824  1450.143333  1440.282414
# Keeling LLC                      1495.175484  1544.883529  1089.263077
# Kiehn-Spinka                     1330.110833  1067.693846  1376.761034
# Koepp Ltd                        1330.406667  1341.886842  1159.166364
# Kuhn-Gusikowski                  1462.815926  1031.678750  1219.907273
# Kulas Inc                        1209.706471  1573.535758  1640.565185
# Pollich LLC                      1030.966538  1444.950000  1150.126000
# Purdy-Kunde                      1824.713684  1571.729412   971.132353
# Sanford and Sons                 1109.499687  1576.542917  1698.797333
# Stokes LLC                       1220.768667  1420.553500  1204.626818
# Trantow-Barrows                  1280.242059  1109.742917  1478.314444
# White-Trantow                    1677.945161  1442.768095  1574.340000
# Will LLC                         1504.788182  1306.380000  1364.380476
#
#                                   quantity
# prod_group                              B1         S1         S2
# name
# Barton LLC                       20.777778  28.040000  28.190476
# Cronin, Oberbrunner and Spencer  26.210526  25.428571  23.740741
# Frami, Hills and Schmidt         25.071429  31.062500  25.142857
# Fritsch, Russel and Anderson     23.714286  26.047619  29.400000
# Halvorson, Crona and Champlin    25.857143  22.333333  17.842105
# Herman LLC                       25.615385  20.375000  27.300000
# Jerde-Hilpert                    23.000000  24.217391  20.696970
# Kassulke, Ondricka and Metz      26.235294  26.388889  25.034483
# Keeling LLC                      24.580645  28.294118  21.653846
# Kiehn-Spinka                     22.791667  19.961538  23.793103
# Koepp Ltd                        23.300000  22.736842  19.969697
# Kuhn-Gusikowski                  25.444444  19.333333  23.363636
# Kulas Inc                        21.294118  26.272727  24.962963
# Pollich LLC                      21.500000  23.136364  25.560000
# Purdy-Kunde                      30.526316  30.235294  20.941176
# Sanford and Sons                 19.375000  28.833333  26.133333
# Stokes LLC                       23.233333  30.100000  21.227273
# Trantow-Barrows                  24.823529  20.583333  25.916667
# White-Trantow                    28.774194  25.142857  24.647059
# Will LLC                         23.818182  23.000000  27.714286

# %% [markdown]
# 對數據進行舍入
#
# 一個簡單（但很有用）的新功能是為DataFrame增加了一個取整方法。在這個版本之前，如果你想對某一列的數據進行舍入，你必須使用np.round或者使用display.float_format來改變顯示。現在我可以控制四捨五入的小數位數，也可以通過在列名字典中指定哪些列要四捨五入。這是很有用的。

# %%
sales_df = sales_df[0:5]
sales_df.round({'ext price':0, 'unit price': 0})
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                 date prod_group
# 0        87.0     3381.0  2014-01-01 07:21:51         B1
# 1        63.0      -63.0  2014-01-01 10:00:47         S2
# 2        91.0     2086.0  2014-01-01 13:24:58         B1
# 3        21.0      863.0  2014-01-01 15:05:22         S1
# 4        83.0      499.0  2014-01-01 23:26:55         S2

# %%
sales_summary.to_excel('data/df-sample-sales3-out.xlsx')

# %% [markdown]
# ### Troubleshooting Merges 解決合併的問題
# 在我處理和合併數據的經驗中，pandas傾向於做我所期望的事情。我發現自己被絆倒的地方之一是當我做一個DataFrame的合併。有時我需要考慮我是否真的想要一個左、右、外或內連接。為了幫助解決這些討厭的問題，有一個新的指標參數，可以幫助你找出為什麼你的合併可能沒有做你所期望的事情。
#
# 在這個例子中，讓我們在我們的數據中加入一個描述。這裡是sales_groups的數據框架。

# %%
import pandas as pd

dt  = {'prod_group': ["B1", "B2", "S1", "S2", "H1"], 
       'Desc': ["Belt-Large", "Belt-Medium", "Shirt-Large", "Shirt-Medium", "Hat-Large"]}

sales_groups = pd.DataFrame(dt)
sales_groups
# Out:
#   prod_group          Desc
# 0         B1    Belt-Large
# 1         B2   Belt-Medium
# 2         S1   Shirt-Large
# 3         S2  Shirt-Medium
# 4         H1     Hat-Large

# %% [markdown]
# 如果我們想把sales_groups數據與我們的銷售數據合併，我們可以這樣做。

# %%
pd.merge(sales_df, sales_groups, on='prod_group', how='left', indicator=True)
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                 date prod_group          Desc _merge
# 0       86.69    3380.91  2014-01-01 07:21:51         B1    Belt-Large   both
# 1       63.16     -63.16  2014-01-01 10:00:47         S2  Shirt-Medium   both
# 2       90.70    2086.10  2014-01-01 13:24:58         B1    Belt-Large   both
# 3       21.05     863.05  2014-01-01 15:05:22         S1   Shirt-Large   both
# 4       83.21     499.26  2014-01-01 23:26:55         S2  Shirt-Medium   both

# %% [markdown]
# 讓我們看看當我們做一個右鍵連接時會發生什麼。

# %%
pd.merge(sales_df, sales_groups, on='prod_group', how='right', indicator=True)
# Out:
#    account number                         name       sku  quantity  \
# 0        740150.0                   Barton LLC  B1-20000      39.0
# 1        218895.0                    Kulas Inc  B1-69924      23.0
# 2             NaN                          NaN       NaN       NaN
# 3        307599.0  Kassulke, Ondricka and Metz  S1-65481      41.0
# 4        714466.0              Trantow-Barrows  S2-77896      -1.0
# 5        412290.0                Jerde-Hilpert  S2-34077       6.0
# 6             NaN                          NaN       NaN       NaN
#
#    unit price  ext price                 date prod_group          Desc  \
# 0       86.69    3380.91  2014-01-01 07:21:51         B1    Belt-Large
# 1       90.70    2086.10  2014-01-01 13:24:58         B1    Belt-Large
# 2         NaN        NaN                  NaN         B2   Belt-Medium
# 3       21.05     863.05  2014-01-01 15:05:22         S1   Shirt-Large
# 4       63.16     -63.16  2014-01-01 10:00:47         S2  Shirt-Medium
# 5       83.21     499.26  2014-01-01 23:26:55         S2  Shirt-Medium
# 6         NaN        NaN                  NaN         H1     Hat-Large
#
#        _merge
# 0        both
# 1        both
# 2  right_only
# 3        both
# 4        both
# 5        both
# 6  right_only

# %%
sales_df["sku"].value_counts()
# Out:
# B1-20000    1
# S2-77896    1
# B1-69924    1
# S1-65481    1
# S2-34077    1
# Name: sku, dtype: int64

# %%
sales_df["sku"].value_counts().to_excel("data/df-sample-sales3-outB.xlsx")

# %% [markdown]
# ### Tabulate 製表
# Pandas有強大的選項來導出DataFrame。然而，我曾有過幾次想以更友好的ASCII方式顯示DataFrame的情況。我很驚喜地發現tabulate程序能夠理解pandas的DataFrames。

# %%
#pip install tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\cti110016\anaconda3\lib\site-packages (0.8.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

print(tabulate(sales_df, tablefmt="fancy_grid"))
# Out:
# ╒═══╤════════╤═════════════════════════════╤══════════╤════╤═══════╤═════════╤═════════════════════╤════╕
# │ 0 │ 740150 │ Barton LLC                  │ B1-20000 │ 39 │ 86.69 │ 3380.91 │ 2014-01-01 07:21:51 │ B1 │
# ├───┼────────┼─────────────────────────────┼──────────┼────┼───────┼─────────┼─────────────────────┼────┤
# │ 1 │ 714466 │ Trantow-Barrows             │ S2-77896 │ -1 │ 63.16 │  -63.16 │ 2014-01-01 10:00:47 │ S2 │
# ├───┼────────┼─────────────────────────────┼──────────┼────┼───────┼─────────┼─────────────────────┼────┤
# │ 2 │ 218895 │ Kulas Inc                   │ B1-69924 │ 23 │ 90.7  │ 2086.1  │ 2014-01-01 13:24:58 │ B1 │
# ├───┼────────┼─────────────────────────────┼──────────┼────┼───────┼─────────┼─────────────────────┼────┤
# │ 3 │ 307599 │ Kassulke, Ondricka and Metz │ S1-65481 │ 41 │ 21.05 │  863.05 │ 2014-01-01 15:05:22 │ S1 │
# ├───┼────────┼─────────────────────────────┼──────────┼────┼───────┼─────────┼─────────────────────┼────┤
# │ 4 │ 412290 │ Jerde-Hilpert               │ S2-34077 │  6 │ 83.21 │  499.26 │ 2014-01-01 23:26:55 │ S2 │
# ╘═══╧════════╧═════════════════════════════╧══════════╧════╧═══════╧═════════╧═════════════════════╧════╛

# %%
headers = list(sales_df)
print(tabulate(sales_df, headers, tablefmt="fancy_grid"))
# Out:
# ╒════╤══════════════════╤═════════════════════════════╤══════════╤════════════╤══════════════╤═════════════╤═════════════════════╤══════════════╕
# │    │   account number │ name                        │ sku      │   quantity │   unit price │   ext price │ date                │ prod_group   │
# ╞════╪══════════════════╪═════════════════════════════╪══════════╪════════════╪══════════════╪═════════════╪═════════════════════╪══════════════╡
# │  0 │           740150 │ Barton LLC                  │ B1-20000 │         39 │        86.69 │     3380.91 │ 2014-01-01 07:21:51 │ B1           │
# ├────┼──────────────────┼─────────────────────────────┼──────────┼────────────┼──────────────┼─────────────┼─────────────────────┼──────────────┤
# │  1 │           714466 │ Trantow-Barrows             │ S2-77896 │         -1 │        63.16 │      -63.16 │ 2014-01-01 10:00:47 │ S2           │
# ├────┼──────────────────┼─────────────────────────────┼──────────┼────────────┼──────────────┼─────────────┼─────────────────────┼──────────────┤
# │  2 │           218895 │ Kulas Inc                   │ B1-69924 │         23 │        90.7  │     2086.1  │ 2014-01-01 13:24:58 │ B1           │
# ├────┼──────────────────┼─────────────────────────────┼──────────┼────────────┼──────────────┼─────────────┼─────────────────────┼──────────────┤
# │  3 │           307599 │ Kassulke, Ondricka and Metz │ S1-65481 │         41 │        21.05 │      863.05 │ 2014-01-01 15:05:22 │ S1           │
# ├────┼──────────────────┼─────────────────────────────┼──────────┼────────────┼──────────────┼─────────────┼─────────────────────┼──────────────┤
# │  4 │           412290 │ Jerde-Hilpert               │ S2-34077 │          6 │        83.21 │      499.26 │ 2014-01-01 23:26:55 │ S2           │
# ╘════╧══════════════════╧═════════════════════════════╧══════════╧════════════╧══════════════╧═════════════╧═════════════════════╧══════════════╛
